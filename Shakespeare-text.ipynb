# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
with open('shakespeare.txt', 'r') as file:
    text = file.read()

# %%
with open('shakespeare.txt', 'r') as file:
    text = file.read()
    lines = text.lower().split('\n')

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence, Tokenizer
words = text_to_word_sequence(text)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(words)
vocabulary_size = len(tokenizer.word_index) + 1
sequences = tokenizer.texts_to_sequences(lines)

# %%
#Find subsequences 
subsequences = []
for sequence in sequences:
    for i in range(1, len(sequence)):
       subsequence = sequence[:i+1]
       subsequences.append(subsequence)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
sequence_length = max([len(sequence) for sequence in sequences])
sequences = pad_sequences(subsequences, maxlen=sequence_length, padding='pre')

# %%
from tensorflow.keras.utils import to_categorical
x, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocabulary_size)

# %%
from tensorflow.keras.models import Sequential
shakesmodel = Sequential()

# %%
from tensorflow.keras.layers import Embedding
shakesmodel.add(Embedding(input_dim = vocabulary_size, 
                    output_dim = 100,
                    input_shape = (sequence_length - 1,)))

# %%
from tensorflow.keras.layers import LSTM 
shakesmodel.add(LSTM(units = 10))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 from tensorflow.keras.layers import LSTM
# ----> 2 shakesmodel.add(LSTM(units = 10))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\training\tracking\base.py:457, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     455 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456 try:
# --> 457   result = method(self, *args, **kwargs)
#     458 finally:
#     459   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\sequential.py:221, in Sequential.add(self, layer)
#     216     self._has_explicit_input_shape = True
#     218 elif self.outputs:
# ...

# %%
from tensorflow.keras.layers import Dropout, Dense
shakesmodel.add(Dropout(0.1))

# %%
#The output layer is a fully-connected layer the size of the vocabulary as it will present 
# a probability for each word of it being the next word in the string.
shakesmodel.add(Dense(units=vocabulary_size, activation ='softmax'))

# %%
shakesmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 9, 100)            58100
# _________________________________________________________________
# dropout (Dropout)            (None, 9, 100)            0
# _________________________________________________________________
# dense (Dense)                (None, 9, 581)            58681
# _________________________________________________________________
# dense_1 (Dense)              (None, 9, 581)            338142
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 581)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9, 581)            338142
# ...
# Total params: 793,065
# Trainable params: 793,065
# Non-trainable params: 0
# ...

# %%
shakesmodel.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from livelossplot import PlotLossesKeras
shakesmodel.fit(x, y,
          callbacks=[PlotLossesKeras()],
          epochs = 500)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from livelossplot import PlotLossesKeras
#       2 shakesmodel.fit(x, y,
#       3           callbacks=[PlotLossesKeras()],
#       4           epochs = 500)
#
# ModuleNotFoundError: No module named 'livelossplot'

# %%
scores = shakesmodel.evaluate(x, y, verbose=0)
print("%s: %.2f%%" % (shakesmodel.metrics_names[1], scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scores = shakesmodel.evaluate(x, y, verbose=0)
#       2 print("%s: %.2f%%" % (shakesmodel.metrics_names[1], scores[1]*100))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py:108, in enable_multi_worker.<locals>._method_wrapper(self, *args, **kwargs)
#     106 def _method_wrapper(self, *args, **kwargs):
#     107   if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108     return method(self, *args, **kwargs)
#     110   # Running inside `run_distribute_coordinator` already.
#     111   if dc_context.get_current_worker_context():
#
# ...

# %%
from tensorflow.keras.layers import Dense
shakesmodel.add(Dense(units=vocabulary_size, activation='softmax'))

shakesmodel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

shakesmodel.fit(x, y, epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 6
#       2 shakesmodel.add(Dense(units=vocabulary_size, activation='softmax'))
#       4 shakesmodel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 6 shakesmodel.fit(x, y, epochs=5)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py:108, in enable_multi_worker.<locals>._method_wrapper(self, *args, **kwargs)
#     106 def _method_wrapper(self, *args, **kwargs):
#     107   if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108     return method(self, *args, **kwargs)
#     110   # Running inside `run_distribute_coordinator` already.
#     111   if dc_context.get_current_worker_context():
#
# ...
